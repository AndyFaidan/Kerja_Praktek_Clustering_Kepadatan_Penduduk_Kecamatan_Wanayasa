# %%
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
from folium.plugins import MarkerCluster
from streamlit_folium import folium_static
import folium
from folium.plugins import MarkerCluster
from streamlit_folium import folium_static

# %% [markdown]
# ## Data Understanding

# %%
# Load data
file_path = "original_table.csv"
df = pd.read_csv(file_path)

# %%
# Menampilkan lima baris pertama dataset
df.head()
# Out:
#         Desa  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  \
# 0  Nangerang  1801  1957  2058  2057  2317  2086  2086  2044  2097  2144
# 1    Simpang  1905  1897  1953  1943  1897  1896  1896  1925  1891  2020
# 2  Sakambang  1401  1596  1630  1641  1583  1583  1583  1498  1592  1567
# 3     Nagrog  3342  2343  2353  2542  2524  2417  2417  2415  2429  2580
# 4    Cibuntu  1427  1444  1469  1524  1574  1574  1574  1571  1622  1642
#
#    2021  2022  Latitude  Longitude
# 0  2144  2092   -6.6971   107.5357
# 1  2020  1934   -6.6828   107.5402
# 2  1570  1496   -6.7110   107.5402
# 3  2580  2412   -6.7132   107.5520
# 4  1640  1605   -6.7079   107.5550

# %%
# Informasi umum tentang dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Desa       15 non-null     object
#  1   2011       15 non-null     int64
#  2   2012       15 non-null     int64
#  3   2013       15 non-null     int64
#  4   2014       15 non-null     int64
#  5   2015       15 non-null     int64
#  6   2016       15 non-null     int64
#  7   2017       15 non-null     int64
#  8   2018       15 non-null     int64
#  9   2019       15 non-null     int64
#  10  2020       15 non-null     int64
#  11  2021       15 non-null     int64
#  12  2022       15 non-null     int64
#  13  Latitude   15 non-null     float64
#  14  Longitude  15 non-null     float64
# dtypes: float64(2), int64(12), object(1)
# memory usage: 1.9+ KB

# %%
# Statistik deskriptif untuk data numerik
df.describe()
# Out:
#               2011         2012         2013         2014         2015  \
# count    15.000000    15.000000    15.000000    15.000000    15.000000
# mean   2594.733333  2646.466667  2726.066667  2847.533333  2843.866667
# std    1054.595215  1092.806012  1102.804119  1174.340111  1167.274228
# min    1269.000000  1347.000000  1354.000000  1414.000000  1419.000000
# 25%    1698.500000  1768.500000  1819.000000  1795.500000  1823.000000
# 50%    2557.000000  2516.000000  2796.000000  2887.000000  2895.000000
# 75%    3280.000000  3166.000000  3365.500000  3668.000000  3574.000000
# max    5003.000000  5386.000000  5399.000000  5533.000000  5705.000000
#
#               2016         2017         2018         2019         2020  \
# count    15.000000    15.000000    15.000000    15.000000    15.000000
# mean   2793.333333  2793.333333  2720.666667  2802.266667  2886.866667
# std    1105.719201  1105.719201  1062.505373  1103.831733  1168.255040
# min    1384.000000  1384.000000  1440.000000  1469.000000  1500.000000
# 25%    1810.500000  1810.500000  1822.000000  1800.500000  1848.000000
# 50%    2958.000000  2958.000000  2621.000000  2553.000000  2771.000000
# 75%    3616.500000  3616.500000  3478.500000  3626.500000  3729.500000
# max    5217.000000  5217.000000  5191.000000  5204.000000  5573.000000
#
#               2021         2022   Latitude  Longitude
# count    15.000000    15.000000  15.000000   15.00000
# mean   2886.933333  2779.000000  -6.673887  107.54342
# std    1167.591383  1114.849702   0.032853    0.01559
# min    1500.000000  1475.000000  -6.713200  107.52240
# 25%    1850.000000  1854.000000  -6.702400  107.53275
# 50%    2770.000000  2684.000000  -6.681200  107.54020
# 75%    3730.000000  3533.000000  -6.650500  107.55350
# max    5570.000000  5486.000000  -6.610300  107.57120

# %%
# Menampilkan nilai unik untuk setiap kolom
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values for {column}:", unique_values)
# Out:
# Unique values for Desa: ['Nangerang' 'Simpang' 'Sakambang' 'Nagrog' 'Cibuntu' 'Sumurugul'
#  'Raharja' 'Wanayasa' 'Babakan' 'Wanasari' 'Legokhuni' 'Ciawi' 'Sukadami'
#  'Taringgul Tonggoh' 'Taringgul Tengah']
# Unique values for 2011: [1801 1905 1401 3342 1427 1596 1269 5003 3279 3281 2204 2557 3199 3211
#  3446]
# Unique values for 2012: [1957 1897 1596 2343 1444 1640 1347 5386 3831 3053 2516 2913 3117 3442
#  3215]
# Unique values for 2013: [2058 1953 1630 2353 1469 1685 1354 5399 3847 3281 2796 2911 3450 3491
#  3214]
# Unique values for 2014: [2057 1943 1641 2542 1524 1648 1414 5533 3876 3789 2887 2981 3547 3483
#  3848]
# Unique values for 2015: [2317 1897 1583 2524 1574 1749 1419 5705 3875 3792 2895 2969 3581 3567
#  3211]
# Unique values for 2016: [2086 1896 1583 2417 1574 1725 1384 5217 3860 3789 2958 2967 3616 3617
#  3211]
# Unique values for 2017: [2086 1896 1583 2417 1574 1725 1384 5217 3860 3789 2958 2967 3616 3617
#  3211]
# Unique values for 2018: [2044 1925 1498 2415 1571 1719 1440 5191 3496 3431 2621 2909 3461 3520
#  3569]
# Unique values for 2019: [2097 1891 1592 2429 1622 1710 1469 5204 3853 3684 2553 3122 3569 3731
#  3508]
# Unique values for 2020: [2144 2020 1567 2580 1642 1676 1500 5573 3726 3673 2771 3064 3733 3808
#  3826]
# Unique values for 2021: [2144 2020 1570 2580 1640 1680 1500 5570 3730 3670 2770 3060 3810 3830]
# Unique values for 2022: [2092 1934 1496 2412 1605 1774 1475 5486 3646 3454 3564 2997 3533 2684]
# Unique values for Latitude: [-6.6971 -6.6828 -6.711  -6.7132 -6.7079 -6.7077 -6.6812 -6.6882 -6.6755
#  -6.6696 -6.6509 -6.6501 -6.6424 -6.6204 -6.6103]
# Unique values for Longitude: [107.5357 107.5402 107.552  107.555  107.5609 107.5476 107.5712 107.5653
#  107.549  107.5224 107.5298 107.5239]

# %%
# Visualisasi data
plt.figure(figsize=(12, 8))

# %%
# Box plot untuk setiap tahun
for year in range(2011, 2023):
    plt.subplot(3, 4, year - 2010)
    plt.boxplot(df[str(year)])
    plt.title(str(year))

    plt.tight_layout()
plt.show()

# %%
# Scatter plot antara Latitude dan Longitude
plt.scatter(df['Longitude'], df['Latitude'])
plt.title('Scatter Plot Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## Data Preparation

# %%
# Menghilangkan kolom Desa, Latitude, dan Longitude dari dataset untuk normalisasi
data_for_normalization = df.drop(['Desa', 'Latitude', 'Longitude'], axis=1)

# %%
# Normalisasi data menggunakan StandardScaler
scaler = StandardScaler()
normalized_data = scaler.fit_transform(data_for_normalization)

# %%
# Membuat DataFrame baru dengan data yang sudah dinormalisasi
df_normalized = pd.DataFrame(normalized_data, columns=data_for_normalization.columns)

# %%
# Menambahkan kembali kolom Desa, Latitude, dan Longitude
df_normalized[['Desa', 'Latitude', 'Longitude']] = df[['Desa', 'Latitude', 'Longitude']]

# %%
# Menampilkan lima baris pertama dari dataset yang sudah dinormalisasi
df_normalized.head()
# Out:
#        2011      2012      2013      2014      2015      2016      2017  \
# 0 -0.779059 -0.653058 -0.627051 -0.696800 -0.467207 -0.662157 -0.662157
# 1 -0.676982 -0.709890 -0.725605 -0.797283 -0.839649 -0.840022 -0.840022
# 2 -1.171664 -0.994995 -1.028775 -1.063474 -1.118093 -1.133031 -1.133031
# 3  0.733452 -0.287442 -0.350163 -0.269306 -0.283647 -0.352297 -0.352297
# 4 -1.146145 -1.138968 -1.179890 -1.166602 -1.126074 -1.141456 -1.141456
#
#        2018      2019      2020      2021      2022       Desa  Latitude  \
# 0 -0.659212 -0.661351 -0.658195 -0.658629 -0.637855  Nangerang   -6.6971
# 1 -0.775143 -0.854524 -0.768062 -0.768558 -0.784552    Simpang   -6.6828
# 2 -1.191128 -1.134906 -1.169429 -1.167494 -1.191220  Sakambang   -6.7110
# 3 -0.297782 -0.350024 -0.271890 -0.272104 -0.340746     Nagrog   -6.7132
# 4 -1.120011 -1.106774 -1.102978 -1.105437 -1.090017    Cibuntu   -6.7079
#
#    Longitude
# 0   107.5357
# 1   107.5402
# 2   107.5402
# 3   107.5520
# 4   107.5550

# %% [markdown]
# ## Modeling

# %%
# Menambahkan density_ranges pada kode yang sudah ada
# Kolom untuk pengelompokan (2011-2022)
kolom_pengelompokan = [str(tahun) for tahun in range(2011, 2020)]

# %%
# Memastikan tidak ada nilai None di dalam kolom_pengelompokan
df[kolom_pengelompokan] = df[kolom_pengelompokan].astype(float)  # Konversi ke tipe data float

# %%
# Kategorikan klaster berdasarkan rentang kepadatan penduduk
population_density_ranges = [1300, 2280, 3744, np.inf]
df["Density Category"] = pd.cut(df[kolom_pengelompokan].mean(axis=1), bins=population_density_ranges, labels=["Tidak Padat", "Padat", "Sangat Padat"])

# %%
# Pilih jumlah klaster
num_clusters = 3

# %%
# Kolom untuk pengelompokan (2012-2021) - Sesuaikan dengan rentang tahun yang diinginkan
kolom_pengelompokan = [str(tahun) for tahun in range(2012, 2022)]

# %%
# Klaster dengan KMeans
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
df["Cluster"] = kmeans.fit_predict(df[kolom_pengelompokan])
# Out:
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Menampilkan hasil klaster di dataset
df.head()
# Out:
#         Desa    2011    2012    2013    2014    2015    2016    2017    2018  \
# 0  Nangerang  1801.0  1957.0  2058.0  2057.0  2317.0  2086.0  2086.0  2044.0
# 1    Simpang  1905.0  1897.0  1953.0  1943.0  1897.0  1896.0  1896.0  1925.0
# 2  Sakambang  1401.0  1596.0  1630.0  1641.0  1583.0  1583.0  1583.0  1498.0
# 3     Nagrog  3342.0  2343.0  2353.0  2542.0  2524.0  2417.0  2417.0  2415.0
# 4    Cibuntu  1427.0  1444.0  1469.0  1524.0  1574.0  1574.0  1574.0  1571.0
#
#      2019  2020  2021  2022  Latitude  Longitude Density Category  Cluster
# 0  2097.0  2144  2144  2092   -6.6971   107.5357      Tidak Padat        1
# 1  1891.0  2020  2020  1934   -6.6828   107.5402      Tidak Padat        1
# 2  1592.0  1567  1570  1496   -6.7110   107.5402      Tidak Padat        1
# 3  2429.0  2580  2580  2412   -6.7132   107.5520            Padat        1
# 4  1622.0  1642  1640  1605   -6.7079   107.5550      Tidak Padat        1

# %%
# List untuk menyimpan inertia (within-cluster sum of squares) dari KMeans
inertias = []
# Coba jumlah klaster dari 1 hingga num_clusters
for k in range(1, num_clusters + 1):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(df[kolom_pengelompokan])
    inertias.append(kmeans.inertia_)
# Out:
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_clusters + 1), inertias, marker='o')
plt.title('Elbow Method')
plt.xlabel('Jumlah Klaster')
plt.ylabel('Inertia')
plt.show()

# %%
# Membuat peta dengan lokasi rata-rata latitude dan longitude
m = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=12)

# %%
# Menambahkan marker cluster
marker_cluster = MarkerCluster().add_to(m)

# %%
# Menambahkan penanda untuk setiap klaster
for i, row in df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']],
                  popup=f"Klaster {row['Cluster'] + 1}: {row['Desa']}").add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce4cc85bf831f1940b9cea82f73e8735 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce4cc85bf831f1940b9cea82f73e8735&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce4cc85bf831f1940b9cea82f73e8735 = L.map(
#                 &quot;map_ce4cc85bf831f1940b9cea82f73e8735&quot;,
#                 {
#                     center: [-6.673886666666666, 107.54342],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_172649e57fc7687d46b8383cb3cb99b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_172649e57fc7687d46b8383cb3cb99b4.addTo(map_ce4cc85bf831f1940b9cea82f73e8735);
#
#
#             var marker_cluster_348b38c6b74dc46fcec47996a401c666 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_348b38c6b74dc46fcec47996a401c666.addTo(map_ce4cc85bf831f1940b9cea82f73e8735);
#
#
#             var marker_9e0efb976cd3ea8ec7bd87bf3e3858e1 = L.marker(
#                 [-6.6971, 107.5357],
#                 {}
#             ).addTo(map_ce4cc85bf831f1940b9cea82f73e8735);
#
#
#         var popup_288603561b3e927e81ccbaba24b4849c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_293e39f573306c8d552889192ab81afb = $(`&lt;div id=&quot;html_293e39f573306c8d552889192ab81afb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Klaster 2: Nangerang&lt;/div&gt;`)[0];
#                 popup_288603561b3e927e81ccbaba24b4849c.setContent(html_293e39f573306c8d552889192ab81afb);
#
#
#
#         marker_9e0efb976cd3ea8ec7bd87bf3e3858e1.bindPopup(popup_288603561b3e927e81ccbaba24b4849c)
#         ;
#
#
#
#
#             var marker_bf78870c9d7d16e30bcfece72fae3dce = L.marker(
#                 [-6.6828, 107.5402],
#                 {}
#             ).addTo(map_ce4cc85bf831f1940b9cea82f73e8735);
#
#
#         var popup_1d22b97cc5970d64ea3a45ac5d34c931 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_282a0fef132e01892874fab7526d1eef = $(`&lt;div id=&quot;html_282a0fef132e01892874fab7526d1eef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Klaster 2: Simpang&lt;/div&gt;`)[0];
#                 popup_1d22b97cc5970d64ea3a45ac5d34c931.setContent(html_282a0fef132e01892874fab7526d1eef);
#
#
#
#         marker_bf78870c9d7d16e30bcfece72fae3dce.bindPopup(popup_1d22b97cc5970d64ea3a45ac5d34c931)
#         ;
#
#
#
#
#             var marker_1e18836ed14b4d1922115ada0eee19e4 = L.marker(
#                 [-6.711, 107.5402],
#                 {}
#             ).addTo(map_ce4cc85bf831f1940b9cea82f73e8735);
#
#
#         var popup_4e72e17c26710a50d05c6c4d0cf7f254 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0a1aae3367e8bebb8d7b75e76d28b07 = $(`&lt;div id=&quot;html_c0a1aae3367e8bebb8d7b75e76d28b07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Klaster 2: Sakambang&lt;/div&gt;`)[0];
#                 popup_4e72e17c26710a50d05c6c4d0cf7f254.setContent(html_c0a1aae3367e8bebb8d7b75e76d28b07);
#
#
#
#         marker_1e18836ed14b4d1922115ada0eee19e4.bindPopup(popup_4e72e17c26710a50d05c6c4d0cf7f254)
#         ;
#
#
#
#
#             var marker_2f28f1d8abffb1efaa641e2385095532 = L.marker(
#                 [-6.7132, 107.552],
#                 {}
#             ).addTo(map_ce4cc85bf831f1940b9cea82f73e8735);
#
#
#         var popup_f8d4f4949877c0144081e572a4188816 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fcffa5cead8f25c2f544706ba4ec776 = $(`&lt;div id=&quot;html_8fcffa5cead8f25c2f544706ba4ec776&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Klaster 2: Nagrog&lt;/div&gt;`)[0];
#                 popup_f8d4f4949877c0144081e572a4188816.setContent(html_8fcffa5cead8f25c2f544706ba4ec776);
#
#
#
#         marker_2f28f1d8abffb1efaa641e2385095532.bindPopup(popup_f8d4f4949877c0144081e572a4188816)
#         ;
#
#
#
#
#             var marker_2895ea23ab83fd39bfd75f047b87c9b0 = L.marker(
#                 [-6.7079, 107.555],
#                 {}
#             ).addTo(map_ce4cc85bf831f1940b9cea82f73e8735);
#
#
#         var popup_bc87b808bd9dd28d8ed8eae240c43360 = L.popup({&quot;max

# %% [markdown]
# ## EVALUASI

# %%
# Data yang digunakan (X_scaled adalah data yang sudah dinormalisasi)
X_scaled = df_normalized.drop(['Desa', 'Latitude', 'Longitude'], axis=1)

# List untuk menyimpan nilai silhouette score
silhouette_scores = []

# Range jumlah klaster yang akan dicoba
range_n_clusters = [2, 3, 4, 5, 6, 7, 8, 9, 10]

for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters, random_state=0, max_iter=50)
    kmeans.fit(X_scaled)

    # Mendapatkan label klaster untuk setiap data point
    cluster_labels = kmeans.labels_

    # Menghitung silhouette score
    silhouette_avg = silhouette_score(X_scaled, cluster_labels)

    # Menyimpan nilai silhouette score
    silhouette_scores.append(silhouette_avg)

    print("For n_clusters = {0}, the silhouette score is {1:.2f}".format(num_clusters, silhouette_avg))

# Plot Silhouette Score
plt.figure(figsize=(10, 6))
plt.plot(range_n_clusters, silhouette_scores, marker='o', linestyle='-', color='b')
plt.title('Silhouette Score for Different Numbers of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.grid(True)
plt.show()
# Out:
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/andy/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# For n_clusters = 2, the silhouette score is 0.59
# For n_clusters = 3, the silhouette score is 0.60
# For n_clusters = 4, the silhouette score is 0.56
# For n_clusters = 5, the silhouette score is 0.52
# For n_clusters = 6, the silhouette score is 0.50
# For n_clusters = 7, the silhouette score is 0.36
# For n_clusters = 8, the silhouette score is 0.34
# For n_clusters = 9, the silhouette score is 0.29
# For n_clusters = 10, the silhouette score is 0.31
